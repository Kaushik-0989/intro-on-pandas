# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaushik-0989/intro-on-pandas/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df=pd.read_csv('Salaries.csv')

# %%
df.head()
#to display first five records
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
# prompt: import pandas library,read this file/content/Salaries.csv

import pandas as pd

# Assuming Salaries.csv is in the /content directory
df = pd.read_csv('/content/Salaries.csv')

# Display the DataFrame
df

# Display the first five records
df.head()

# Display the last five records
df.tail()

# Get the dimensions of the DataFrame
df.shape

# Get the column names
df.columns

# Get the data type of the DataFrame
type(df)

# Check for null values
df.isnull()

# Set the display option to show all rows (use with caution for large datasets)
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df.iloc[0:10,0:4]
# Out:
#         rank discipline  phd  service
# 0       Prof          B   56       49
# 1       Prof          A   12        6
# 2       Prof          A   23       20
# 3       Prof          A   40       31
# 4       Prof          B   20       18
# 5       Prof          A   20       20
# 6  AssocProf          A   20       17
# 7       Prof          A   18       18
# 8       Prof          A   29       19
# 9       Prof          A   51       51

# %%
# prompt: can you calculate measures of central tendency for salary column and measures of dispersion

import pandas as pd

# Assuming Salaries.csv is in the /content directory
df = pd.read_csv('/content/Salaries.csv')

# Calculate measures of central tendency
mean_salary = df['salary'].mean()
median_salary = df['salary'].median()
mode_salary = df['salary'].mode()

# Calculate measures of dispersion
variance_salary = df['salary'].var()
std_dev_salary = df['salary'].std()
min_salary = df['salary'].min()
max_salary = df['salary'].max()
range_salary = max_salary - min_salary  # Calculate the range


print(f"Mean Salary: {mean_salary}")
print(f"Median Salary: {median_salary}")
print(f"Mode Salary: {mode_salary}")
print(f"Variance of Salary: {variance_salary}")
print(f"Standard Deviation of Salary: {std_dev_salary}")
print(f"Minimum Salary: {min_salary}")
print(f"Maximum Salary: {max_salary}")
print(f"Range of Salary: {range_salary}")
# Out:
# Mean Salary: 108023.78205128205
# Median Salary: 104671.0
# Mode Salary: 0    92000
# Name: salary, dtype: int64
# Variance of Salary: 800531254.0427904
# Standard Deviation of Salary: 28293.661022264165
# Minimum Salary: 57800
# Maximum Salary: 186960
# Range of Salary: 129160

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['Accept'])
plt.xlabel('accept')
plt.ylabel('frequency')
plt.title('histogram of accept')
# Out:
# Text(0.5, 1.0, 'histogram of accept')

# %%
sn.histplot(df1['Accept'])
plt.show()

# %%
plt.plot(df1['Accept'],df1['SAT'],'rs')

# %%
plt.plot(df1['Accept'],df1['SAT'],'rs')
plt.xlabel('accept')
plt.ylabel('Top10')
plt.title('Accept vs Top10')
plt.show()

# %%
plt.figure()
plt.plot(df1['Accept'],df1['SAT'],'rs')
plt.xlabel('accept')
plt.ylabel('Top10')
plt.title('Accept vs Top10')
plt.show()

# %%
sn.pairplot(df1)

# %%
sn.pairplot(df1.iloc[:,1:3])

# %%
sn.distplot(df1['Accept'])
import warnings
warnings.filterwarnings('ignore')
plt.show()

# %%
plt.boxplot(df1['Accept'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e2b647db750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e2b647cf7d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e2b647dae50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e2b6698ab90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e2b644a1a10>],
#  'means': []}

# %%
plt.boxplot(df1['Accept'])
plt.show()

# %%
# prompt: chnge thecolour of histogram to grey

import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df1['Accept'], color='gray') # Set color to gray
plt.show()
